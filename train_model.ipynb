# %%
from ultralytics import YOLO
import yaml

# %%
with open('settings.yml', 'r') as f:
    cfg = yaml.safe_load(f)

parameters = cfg

imgsz  = parameters['imgsz']     # 736 is fine (multiple of 32)
device = parameters['device']     # 'mps' for Apple Silicon

# model = YOLO('yolo11n.pt')
model = YOLO('playeriden/exp2/weights/last.pt')

# %%
# 3) Train
results = model.train(
    data='training_para.yml',  # dict: {path, train, val, test, nc, names}
    imgsz=imgsz,
    epochs=100,
    batch=24,                 # likely too big for MPS; try 8–32 if OOM
    device=device,             # 'mps' | '0' | 'cpu'
    project="playeriden",
    name="exp2",
    cache=True,
    patience=30,
    optimizer="AdamW",
    lr0=0.001,
    resume=True
)
# Out:
# Ultralytics 8.3.223 🚀 Python-3.12.11 torch-2.9.0 MPS (Apple M3 Max)
# ...
